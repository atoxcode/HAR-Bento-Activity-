# %%
# matplotlib inline

# %%
from glob import glob
import pandas as pd
import numpy as np

# %%
csv_file_list = glob("train/*")

# %%
df = pd.read_csv(csv_file_list[10])

# %%
df.plot()
# Out:
# <AxesSubplot:>
