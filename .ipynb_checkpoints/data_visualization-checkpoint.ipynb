# %%
# matplotlib inline

# %%
from glob import glob
import pandas as pd
import numpy as np

# %%
csv_file_list = glob("train/*")

# %%
dataset = pd.read_csv('train/segment0.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
print(X)
print(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ef02d64c2b69> in <module>
# ----> 1 dataset = pd.read_csv('train/*')
#       2 X = dataset.iloc[:, :-1].values
#       3 y = dataset.iloc[:, -1].values
#       4 print(X)
#       5 print(y)
#
# ...

# %%
df = pd.read_csv(csv_file_list[0])

# %%
df.plot()
